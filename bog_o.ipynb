# %% [markdown]
# # Bi O algorithm Analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Now, plotting a function is as easy as the following three lines of code. It shows the plot of a function  7n2+6n+5
#   in the range  1≤n≤100
#  . Note that the scale of the  y
#  -axis adjusts nicely.

# %%
n = np.linspace(1, 100)
plt.plot(7 * n * n + 6 * n + 5)
plt.show()

# %% [markdown]
# Now, let us add a function  20n
#   to the previous example to visualize that  20n
#   grows slower than  7n2+6n+5
#  .

# %%
n = np.linspace(1, 100)
plt.plot(7 * n * n + 6 * n + 5, label = "7n^2 + 6n + 5")
plt.plot(20 * n, label = "20n")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# Common rules
# Before proceeding with visualizations, let's review the common rules of comparing the order of growth of functions arising frequently in algorithm analysis.
#
# Multiplicative constants can be omitted:  c⋅f⪯f
#  . Examples:  5n2⪯n2
#  ,  n23⪯n2
#  .
# Out of two polynomials, the one with larger degree grows faster:  na⪯nb
#   for  0≤a≤b
#  . Examples:  n≺n2
#  ,  n⎯⎯√≺n2/3
#  ,  n2≺n3
#  ,  n0≺n⎯⎯√
#  .
# Any polynomial grows slower than any exponential:  na≺bn
#   for  a≥0,b>1
#  . Examples:  n3≺2n
#  ,  n10≺1.1n
#  .
# Any polylogarithm grows slower than any polynomial:  (logn)a≺nb
#   for  a,b>0
#  . Examples:  (logn)3≺n⎯⎯√
#  ,  nlogn≺n2
#  .
# Smaller terms can be ommited: if  f≺g
#  , then  f+g⪯g
#  . Examples:  n2+n⪯n2
#  ,  2n+n9⪯2n
#  .
#
#
#
# Rule 5: Smaller terms can be omitted
# Consider 7n2+6n+5
#  again. Both 6n
#  and 5
#  grow slower than 7n2
# . For this reason, they can be omitted. To visualize this, let's first plot the functions 7n2+6n+5
#  and 7n2
#  for 1≤n≤5
# .

# %%
n = np.linspace(1, 5)
plt.plot(7 * n * n + 6 * n + 5, label = "7n^2 + 6n + 5")
plt.plot(7 * n * n, label = "7n^2")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# As expected,  7n2+6n+5
#   is always larger than  7n2
#   (as  n
#   is positive). Next, we plot the same two functions but for  1≤n≤100
#  .

# %%
n = np.linspace(1, 100)
plt.plot(7 * n * n + 6 * n + 5, label = "7n^2 + 6n +5")
plt.plot(7 * n * n, label = "7n^2")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# We see that as  n
#   grows, the contribution of  6n+5
#   becomes more and more negligible.
#
# Another way of justifying this, is to plot the function 7n2+6n+57n2
# .

# %%
x = np.linspace(1, 100)
plt.plot(n, (7 * n * n + 6 * n + 5) / (7 * n * n))
plt.show()

# %% [markdown]
# As we see, as  n
#   grows, the fraction approaches 1.

# %% [markdown]
# Rule 1: Multiplicative constants can be ommitted
# In terms of big-O notation,  7n2+6n+5=O(n2)
#  , i.e.,  7n2+6n+5
#   grows no faster than  n2
#  . This again can be visualized by plotting their fraction. As we see, their fraction is always at most 18 and approaches 7. In other words,  7n2+6n+5≤18n2
#   for all  n≥1
#  .

# %%
n = np.linspace(1, 100)
plt.plot(n, (7 * n * n + 6 * n + 5 )/ (n * n))
plt.show()

# %% [markdown]
# Rule 2: Out of two polynomials, the one with larger degree grows faster
# For constants  a>b>0
#  ,  na
#   grows faster than  nb
#  . This, in particular, means that  nb=O(na)
#  . To visualize it, let's plot  n
#  ,  n2
#  , and  n3
#  .

# %%
n = np.linspace(1, 10)
plt.plot(n , n , label = "n")
plt.plot(n, n * n, label = "n^2")
plt.plot(n, n * n * n, label = "n^3")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# Let's now see what happens on a bigger scale: instead of the range  1≤n≤10
#  , consider the range  1≤n≤100
#  .

# %%
n = np.linspace(1, 100)
plt.plot(n, n, label = "n")
plt.plot(n, n * n, label = "n^2")
plt.plot(n, n * n * n, label = "n ^3")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# Rule 3: Any polynomial grows slower than any exponential
# Let's plot  n4
#   and  2n
#   in the range  1≤n≤10
#  .

# %%
n = np.linspace(1, 10)
plt.plot(n, n ** 4, label = "n^4")
plt.plot(n, 2 ** n, label = "2^n")
plt.legend("upper left")
plt.show()

# %% [markdown]
# The plot reveals that in this range  n4
#   is always greater than  2n
#  . This however does not mean that  n4
#   grows faster than  2n
#  ! To ensure this, let's take a look at a larger range  1≤n≤20
#  .

# %%
n = np.linspace(1, 20)
plt.plot(n, n ** 4, label = "n^4")
plt.plot(n, 2 ** n, label = "2^n")
plt.legend("upper left")
plt.show()

# %% [markdown]
# Rule 4: Any polylogarithm grows slower than any polynomial
# To visualize this rule, we start by plotting the two most standard representatives:  logn
#   and  n
#  . The following plot shows that  logn
#   indeed grows slower than  n
#  .

# %%
n = np.linspace(1, 20)
plt.plot(n, n , label = "n")
plt.plot(n, np.log(n), label = "log n")
plt.legend("upper left")
plt.show()

# %% [markdown]
# Now consider a more exotic example:  (logn)3
#   versus  n⎯⎯√
#   (recall that  n⎯⎯√
#   is a polynomial function since  n⎯⎯√=n0.5
#  ).

# %%
n = np.linspace(1, 100)
plt.plot(n, n ** .5, label = "n ^ .5")
plt.plot(n, np.log(n) ** 3, label = "log n ^ 3")
plt.legend("upper left")
plt.show()

# %% [markdown]
# This looks strange: it seems that  (logn)3
#   grows faster than  n⎯⎯√
#  . Let's do the standard trick: increase the range from  [1,100]
#   to, say,  [1,1000000]
#  .

# %%
n = np.linspace(1, 10 ** 6)
plt.plot(n, n ** .5, label = "n ** .5")
plt.plot(n, np.log(n) ** 3, label = "log n ^3")
plt.legend("upper left")
plt.show()

# %% [markdown]
# Surprisingly, the logaritmic function is still above the polynomial one! This shows that it is in fact dangerous to decide which function grows faster just by looking at how they behave for some not so large values of  n
#  . The rule "any polynomial grows faster than any polylogarithm" means that eventually the polynomial function will become larger and larger than polylogarithmic. But the rule does not specify for what value of  n
#   this happens for the first time.
#
# To finally ensure that  n⎯⎯√
#   outperforms  (logn)3
#   eventually, let's increase the range to  10^8
#  .

# %%
n = np.linspace(1, 10 ** 8)
plt.plot(n, n ** .5, label = "n ** .5")
plt.plot(n, np.log(n) ** 3, label = "log n^3")
plt.legend("upper left")
plt.show()

# %% [markdown]
# Also, let's consider an even large interval to make sure that these two functions don't switch back.

# %%
n = np.linspace(1, 10 ** 15)
plt.plot(n, n ** .5, label = "n^ .5")
plt.plot(n, np.log(n) ** 3, label = "log(n)^3")
plt.legend("upper left")
plt.show()

# %%
# check the run time
n = np.linspace(0, 100)
plt.plot(n, 100 * n + 300)
plt.plot(n, 6 * n * n)
plt.legend("upper left")
plt.show()

# %% [markdown]
# **Exercise**

# %% [markdown]
# - As the final exercise, try to find the value of  n
#   where  n0.1
#   becomes larger than  (logn)5
#  .

# %%
n = np.linspace(1, 100)
plt.plot(n, n ** .1, label = "n^ 01")
plt.plot(n, np.log(n) ** 5, label = "log n^5")
plt.legend("upper left")
plt.show()
